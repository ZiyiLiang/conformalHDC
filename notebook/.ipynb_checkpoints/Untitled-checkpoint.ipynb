# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import sys
import os

sys.path.append('../')
from conformalHDC.models import *
from conformalHDC.methods import *
from conformalHDC.utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
mitt_file = r"C:\Users\liang\Documents\GitHub\conformalHDC\data\neuron_data\Mitt"

# %%
# List all .npy files in the folder
npy_files = [f for f in os.listdir(mitt_file) if f.endswith('.npy')]

# %%
# Load each .npy file
loaded_data = {}
for file in npy_files:
    file_path = os.path.join(mitt_file, file)
    data = np.load(file_path)
    loaded_data[file] = data  # Store loaded data in a dictionary
    print(f"Loaded {file} with shape {data.shape}")
# Out:
# Loaded mitt_lfp_data_sampled.npy with shape (292, 400, 21)
# Loaded mitt_spike_data_binned.npy with shape (292, 104, 400)
# Loaded mitt_trial_info.npy with shape (292, 4)
