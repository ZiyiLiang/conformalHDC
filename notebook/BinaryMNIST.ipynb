# %%
import torch
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms
import numpy as np, time, os
from collections import Counter
import matplotlib.pyplot as plt

# %%
# Repro / device
def set_seed(seed=123):
    import random
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

set_seed(123)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DEVICE
# Out:
# device(type='cpu')

# %%
@torch.no_grad()
def bipolar_sign(x: torch.Tensor) -> torch.Tensor:
    # We map to {-1,+1}; ties go to +1 for determinism.
    return torch.where(x >= 0, torch.ones_like(x), -torch.ones_like(x))

def _rand_bip(shape, device=None):
    device = device or DEVICE
    r = torch.randint(0, 2, shape, device=device, dtype=torch.int8)
    return r.float().mul_(2).sub_(1)  # {0,1} -> {-1,+1}

def make_position_hvs(n_positions: int, dim: int, device=None) -> torch.Tensor:
    # We assign each pixel position a random bipolar hypervector.
    return _rand_bip((n_positions, dim), device=device or DEVICE)

@torch.no_grad()
def encode_binary_images_to_hvs(imgs: torch.Tensor,
                                pos_hvs: torch.Tensor,
                                threshold: float = 0.5) -> torch.Tensor:
    # Strategy: binarize -> flatten -> sum position HVs for '1' pixels -> majority sign.
    B, C, H, W = imgs.shape
    assert C == 1
    P = H * W
    x = (imgs.view(B, P) >= threshold).to(torch.float32).to(pos_hvs.device)  # [B,P], {0,1}
    hv = x @ pos_hvs                                                            # [B,D]
    return bipolar_sign(hv)

@torch.no_grad()
def build_class_prototypes(enc_loader: DataLoader,
                           pos_hvs: torch.Tensor,
                           n_classes: int = 10,
                           threshold: float = 0.5) -> torch.Tensor:
    # We bundle all sample HVs per class and sign to get one prototype per class.
    D = pos_hvs.shape[1]
    accum = torch.zeros((n_classes, D), device=pos_hvs.device, dtype=torch.float32)
    for imgs, labels in enc_loader:
        imgs   = imgs.to(pos_hvs.device, non_blocking=True)
        labels = labels.to(pos_hvs.device, non_blocking=True)
        hvs = encode_binary_images_to_hvs(imgs, pos_hvs, threshold=threshold)
        for c in range(n_classes):
            m = (labels == c)
            if m.any():
                accum[c] += hvs[m].sum(dim=0)
    return bipolar_sign(accum)

@torch.no_grad()
def cosine_sim(a: torch.Tensor, b: torch.Tensor) -> torch.Tensor:
    a32 = a.float(); b32 = b.float()
    an = torch.linalg.norm(a32, dim=1, keepdim=True).clamp_min_(1e-8)
    bn = torch.linalg.norm(b32, dim=1, keepdim=True).clamp_min_(1e-8).T
    return (a32 @ b32.T) / (an * bn)

@torch.no_grad()
def predict_with_prototypes(imgs: torch.Tensor,
                            pos_hvs: torch.Tensor,
                            prototypes: torch.Tensor,
                            threshold: float = 0.5) -> torch.Tensor:
    hvs = encode_binary_images_to_hvs(imgs, pos_hvs, threshold=threshold)
    sims = cosine_sim(hvs, prototypes)
    return sims.argmax(dim=1)

@torch.no_grad()
def evaluate_loader(data_loader: DataLoader,
                    pos_hvs: torch.Tensor,
                    prototypes: torch.Tensor,
                    threshold: float = 0.5) -> float:
    correct = total = 0
    for imgs, labels in data_loader:
        imgs   = imgs.to(pos_hvs.device, non_blocking=True)
        labels = labels.to(pos_hvs.device, non_blocking=True)
        preds = predict_with_prototypes(imgs, pos_hvs, prototypes, threshold=threshold)
        correct += (preds == labels).sum().item()
        total   += labels.numel()
    return 100.0 * correct / total

class FilteredMNIST(datasets.MNIST):
    """
    A custom MNIST dataset that filters out specified labels upon initialization.
    The resulting object is a standard MNIST dataset instance.
    """
    def __init__(self, root, train=True, transform=None, target_transform=None,
                 download=False, labels_to_remove=None):
        # First, call the original MNIST constructor to load everything.
        super().__init__(root, train=train, transform=transform,
                         target_transform=target_transform, download=download)

        # If no labels to remove are specified, we're done.
        if labels_to_remove is None:
            return

        # Find the indices of samples that we want to KEEP.
        indices_to_keep = [i for i, target in enumerate(self.targets) if target not in labels_to_remove]

        # Overwrite the .data and .targets attributes with the filtered versions.
        # This is the crucial step that makes the object behave as desired.
        self.data = self.data[indices_to_keep]
        self.targets = self.targets[indices_to_keep]

# %%
transform = transforms.ToTensor()

# --- Load the (filtered) dataset ---
train_ds = FilteredMNIST(root="/content/data", train=True, download=True, labels_to_remove=[9])
test_ds = datasets.MNIST(root="/content/data", train=False, download=True)

# --- Count the Label Distributions ---
train_label_distribution = Counter(train_ds.targets.numpy())
test_label_distribution = Counter(test_ds.targets.numpy())

labels = sorted(test_label_distribution.keys()) # Should be [0, 1, ..., 9]
train_counts = [train_label_distribution.get(label, 0) for label in labels] # Use .get() to handle the missing label 9
test_counts = [test_label_distribution[label] for label in labels]

x = np.arange(len(labels))  # The label locations on the x-axis
width = 0.35  # The width of the bars

fig, ax = plt.subplots(figsize=(12, 7))
rects1 = ax.bar(x - width/2, train_counts, width, label='Train Set (Label 9 removed)', color='tab:blue')
rects2 = ax.bar(x + width/2, test_counts, width, label='Test Set', color='tab:red')

ax.set_ylabel('Number of Samples')
ax.set_xlabel('Digit Label')
ax.set_title('MNIST Label Distribution in Train and Test Sets')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

ax.bar_label(rects1, padding=3, rotation=45, fontsize=8)
ax.bar_label(rects2, padding=3, rotation=45, fontsize=8)

fig.tight_layout()
plt.show()

# %%
BATCH_SIZE = 512

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,  num_workers=0, pin_memory=False)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=False)

# %%
DIM = 10_000  # We typically use 8k–20k; 10k is a solid default.
H, W = 28, 28
P = H * W

pos_hvs = make_position_hvs(P, DIM, device=DEVICE)
pos_hvs.shape, pos_hvs.device
# Out:
# (torch.Size([784, 10000]), device(type='cpu'))

# %%
t0 = time.time()
prototypes = build_class_prototypes(train_loader, pos_hvs, n_classes=10, threshold=0.5)
print("Prototypes:", prototypes.shape, "built in %.2fs" % (time.time() - t0))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 t0 = time.time()
# ----> 2 prototypes = build_class_prototypes(train_loader, pos_hvs, n_classes=10, threshold=0.5)
#       3 print("Prototypes:", prototypes.shape, "built in %.2fs" % (time.time() - t0))
#
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# Cell In[22], line 35, in build_class_prototypes(enc_loader, pos_hvs, n_classes, threshold)
#      33 D = pos_hvs.shape[1]
#      34 accum = torch.zeros((n_classes, D), device=pos_hvs.device, dtype=torch.float32)
# ---> 35 for imgs, labels in enc_loader:
#      36     imgs   = imgs.to(pos_hvs.device, non_blocking=True)
#      37     labels = labels.to(pos_hvs.device, non_blocking=True)
#
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\data\dataloader.py:734, in _BaseDataLoaderIter.__next__(self)
#     731 if self._sampler_iter is None:
#     732     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     733     self._reset()  # type: ignore[call-arg]
# --> 734 data = self._next_data()
#     735 self._num_yielded += 1
#     736 if (
#     737     self._dataset_kind == _DatasetKind.Iterable
#     738     and self._IterableDataset_len_called is not None
#     739     and self._num_yielded > self._IterableDataset_len_called
#     740 ):
#
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\data\dataloader.py:790, in _SingleProcessDataLoaderIter._next_data(self)
#     788 def _next_data(self):
#     789     index = self._next_index()  # may raise StopIteration
# --> 790     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     791     if self._pin_memory:
#     792         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\data\_utils\fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\data\_utils\collate.py:398, in default_collate(batch)
#     337 def default_collate(batch):
#     338     r"""
#     339     Take in a batch of data and put the elements within the batch into a tensor with an additional outer dimension - batch size.
#     340
#    (...)
#     396         >>> default_collate(batch)  # Handle `CustomType` automatically
#     397     """
# --> 398     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\data\_utils\collate.py:211, in collate(batch, collate_fn_map)
#     208 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     210 if isinstance(elem, tuple):
# --> 211     return [
#     212         collate(samples, collate_fn_map=collate_fn_map)
#     213         for samples in transposed
#     214     ]  # Backwards compatibility.
#     215 else:
#     216     try:
#
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\data\_utils\collate.py:212, in <listcomp>(.0)
#     208 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     210 if isinstance(elem, tuple):
#     211     return [
# --> 212         collate(samples, collate_fn_map=collate_fn_map)
#     213         for samples in transposed
#     214     ]  # Backwards compatibility.
#     215 else:
#     216     try:
#
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\data\_utils\collate.py:240, in collate(batch, collate_fn_map)
#     232         except TypeError:
#     233             # The sequence type may not support `copy()` / `__setitem__(index, item)`
#     234             # or `__init__(iterable)` (e.g., `range`).
#     235             return [
#     236                 collate(samples, collate_fn_map=collate_fn_map)
#     237                 for samples in transposed
#     238             ]
# --> 240 raise TypeError(default_collate_err_msg_format.format(elem_type))
#
# TypeError: default_collate: batch must contain tensors, numpy arrays, numbers, dicts or lists; found <class 'PIL.Image.Image'>

# %%
acc = evaluate_loader(test_loader, pos_hvs, prototypes, threshold=0.5)
print(f"Test accuracy (MNIST): {acc:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 acc = evaluate_loader(test_loader, pos_hvs, prototypes, threshold=0.5)
#       2 print(f"Test accuracy (MNIST): {acc:.2f}%")
#
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# Cell In[22], line 67, in evaluate_loader(data_loader, pos_hvs, prototypes, threshold)
#      61 @torch.no_grad()
#      62 def evaluate_loader(data_loader: DataLoader,
#      63                     pos_hvs: torch.Tensor,
#      64                     prototypes: torch.Tensor,
#      65                     threshold: float = 0.5) -> float:
#      66     correct = total = 0
# ---> 67     for imgs, labels in data_loader:
#      68         imgs   = imgs.to(pos_hvs.device, non_blocking=True)
#      69         labels = labels.to(pos_hvs.device, non_blocking=True)
#
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\data\dataloader.py:734, in _BaseDataLoaderIter.__next__(self)
#     731 if self._sampler_iter is None:
#     732     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     733     self._reset()  # type: ignore[call-arg]
# --> 734 data = self._next_data()
#     735 self._num_yielded += 1
#     736 if (
#     737     self._dataset_kind == _DatasetKind.Iterable
#     738     and self._IterableDataset_len_called is not None
#     739     and self._num_yielded > self._IterableDataset_len_called
#     740 ):
#
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\data\dataloader.py:790, in _SingleProcessDataLoaderIter._next_data(self)
#     788 def _next_data(self):
#     789     index = self._next_index()  # may raise StopIteration
# --> 790     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     791     if self._pin_memory:
#     792         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\data\_utils\fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\data\_utils\collate.py:398, in default_collate(batch)
#     337 def default_collate(batch):
#     338     r"""
#     339     Take in a batch of data and put the elements within the batch into a tensor with an additional outer dimension - batch size.
#     340
#    (...)
#     396         >>> default_collate(batch)  # Handle `CustomType` automatically
#     397     """
# --> 398     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\data\_utils\collate.py:211, in collate(batch, collate_fn_map)
#     208 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     210 if isinstance(elem, tuple):
# --> 211     return [
#     212         collate(samples, collate_fn_map=collate_fn_map)
#     213         for samples in transposed
#     214     ]  # Backwards compatibility.
#     215 else:
#     216     try:
#
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\data\_utils\collate.py:212, in <listcomp>(.0)
#     208 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     210 if isinstance(elem, tuple):
#     211     return [
# --> 212         collate(samples, collate_fn_map=collate_fn_map)
#     213         for samples in transposed
#     214     ]  # Backwards compatibility.
#     215 else:
#     216     try:
#
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\data\_utils\collate.py:240, in collate(batch, collate_fn_map)
#     232         except TypeError:
#     233             # The sequence type may not support `copy()` / `__setitem__(index, item)`
#     234             # or `__init__(iterable)` (e.g., `range`).
#     235             return [
#     236                 collate(samples, collate_fn_map=collate_fn_map)
#     237                 for samples in transposed
#     238             ]
# --> 240 raise TypeError(default_collate_err_msg_format.format(elem_type))
#
# TypeError: default_collate: batch must contain tensors, numpy arrays, numbers, dicts or lists; found <class 'PIL.Image.Image'>

# %%
for s, l in train_loader:
    print(s,l)
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\data\dataloader.py:1285, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1284 try:
# -> 1285     data = self._data_queue.get(timeout=timeout)
#    1286     return (True, data)
#
# File ~\anaconda3\envs\hdc\lib\multiprocessing\queues.py:114, in Queue.get(self, block, timeout)
#     113     if not self._poll(timeout):
# --> 114         raise Empty
#     115 elif not self._poll():
#
# Empty:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 for s, l in train_loader:
#       2     print(s,l)
#
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\data\dataloader.py:734, in _BaseDataLoaderIter.__next__(self)
#     731 if self._sampler_iter is None:
#     732     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     733     self._reset()  # type: ignore[call-arg]
# --> 734 data = self._next_data()
#     735 self._num_yielded += 1
#     736 if (
#     737     self._dataset_kind == _DatasetKind.Iterable
#     738     and self._IterableDataset_len_called is not None
#     739     and self._num_yielded > self._IterableDataset_len_called
#     740 ):
#
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\data\dataloader.py:1492, in _MultiProcessingDataLoaderIter._next_data(self)
#    1489     return self._process_data(data, worker_id)
#    1491 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1492 idx, data = self._get_data()
#    1493 self._tasks_outstanding -= 1
#    1494 if self._dataset_kind == _DatasetKind.Iterable:
#    1495     # Check for _IterableDatasetStopIteration
#
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\data\dataloader.py:1454, in _MultiProcessingDataLoaderIter._get_data(self)
#    1450     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1451     # need to call `.task_done()` because we don't use `.join()`.
#    1452 else:
#    1453     while True:
# -> 1454         success, data = self._try_get_data()
#    1455         if success:
#    1456             return data
#
# File ~\anaconda3\envs\hdc\lib\site-packages\torch\utils\data\dataloader.py:1298, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1296 if len(failed_workers) > 0:
#    1297     pids_str = ", ".join(str(w.pid) for w in failed_workers)
# -> 1298     raise RuntimeError(
#    1299         f"DataLoader worker (pid(s) {pids_str}) exited unexpectedly"
#    1300     ) from e
#    1301 if isinstance(e, queue.Empty):
#    1302     return (False, None)
#
# RuntimeError: DataLoader worker (pid(s) 48868, 34728) exited unexpectedly
